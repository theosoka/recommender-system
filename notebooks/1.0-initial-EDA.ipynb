# %% [markdown]
# ## heading

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st
from sklearn import ensemble, tree, linear_model
from sklearn.model_selection import train_test_split
import missingno as msno

# %%
df = pd.read_csv("/Users/polina/PycharmProjects/recommendation_system/recommendation-system/data/external/training_set/log_mini.csv")
train, test = train_test_split(df,test_size = 0.2)

# %%
tracks_df = pd.read_csv("/Users/polina/PycharmProjects/recommendation_system/recommendation-system/data/external/track_features/tf_mini.csv")

# %%
df = df.rename(columns={"track_id_clean": "track_id"})

# %%
df.head()
# Out:
#                                session_id  session_position  session_length  \
# 0  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1              20
# 1  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2              20
# 2  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3              20
# 3  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4              20
# 4  0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5              20
#
#                                  track_id  skip_1  skip_2  skip_3  \
# 0  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False   False   False
# 1  t_9099cd7b-c238-47b7-9381-f23f2c1d1043   False   False   False
# 2  t_fc5df5ba-5396-49a7-8b29-35d0d28249e0   False   False   False
# 3  t_23cff8d6-d874-4b20-83dc-94e450e8aa20   False   False   False
# 4  t_64f3743c-f624-46bb-a579-0f3f9a07a123   False   False   False
#
#    not_skipped  context_switch  no_pause_before_play  ...  \
# ...

# %%
tracks_df
# Out:
#                                      track_id    duration  release_year  \
# 0      t_a540e552-16d4-42f8-a185-232bd650ea7d  109.706673          1950
# 1      t_67965da0-132b-4b1e-8a69-0ef99b32287c  187.693329          1950
# 2      t_0614ecd3-a7d5-40a1-816e-156d5872a467  160.839996          1951
# 3      t_070a63a0-744a-434e-9913-a97b02926a29  175.399994          1951
# 4      t_d6990e17-9c31-4b01-8559-47d9ce476df1  369.600006          1951
# ...                                       ...         ...           ...
# 50699  t_402930af-4174-47ec-b1fd-593d93597624  184.686798          2018
# 50700  t_e5f9a069-a893-452e-ab21-49b4eaebfbd0  251.813324          2018
# 50701  t_3983306d-13b4-4027-9391-7236ca93d2bf  157.520004          2018
# 50702  t_74eb6e99-210b-440c-8d7b-4db6617d1c80  129.105392          2018
# 50703  t_aec0dda3-19b4-4222-be07-327c12f21456  213.689392          2018
#
#        us_popularity_estimate  acousticness  beat_strength  bounciness  \
# ...

# %%
joined_df = df.join(tracks_df.set_index("track_id"), on="track_id")

# %%
joined_df
# Out:
#                                     session_id  session_position  \
# 0       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 1
# 1       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 2
# 2       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 3
# 3       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 4
# 4       0_00006f66-33e5-4de7-a324-2d18e439fc1e                 5
# ...                                        ...               ...
# 167875  0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                16
# 167876  0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                17
# 167877  0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                18
# 167878  0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                19
# 167879  0_0eaeef5d-25e9-4429-bd55-af15d3604c9f                20
#
#         session_length                                track_id  skip_1  \
# 0                   20  t_0479f24c-27d2-46d6-a00c-7ec928f2b539   False
# ...

# %%
tracks_df.describe()
# Out:
#            duration  release_year  us_popularity_estimate  acousticness  \
# count  50704.000000  50704.000000            50704.000000  50704.000000
# mean     222.267980   2010.324748               99.455131      0.250336
# std       72.224839     11.471866                1.139222      0.276047
# min       30.013330   1950.000000               90.018900      0.000000
# 25%      183.933334   2009.000000               99.509670      0.025291
# 50%      214.866669   2015.000000               99.865444      0.135821
# 75%      250.426666   2017.000000               99.961131      0.406142
# max     1787.760986   2018.000000               99.999997      0.995796
#
#        beat_strength    bounciness  danceability  dyn_range_mean  \
# count   50704.000000  50704.000000  50704.000000    50704.000000
# mean        0.492075      0.514526      0.611742        8.215950
# std         0.158102      0.182595      0.166146        2.410626
# ...

# %%
train.describe()
# Out:
#        session_position  session_length  context_switch  no_pause_before_play  \
# count     134304.000000   134304.000000   134304.000000         134304.000000
# mean           9.339081       17.650651        0.041019              0.767833
# std            5.456103        3.421748        0.198335              0.422217
# min            1.000000       10.000000        0.000000              0.000000
# 25%            5.000000       15.000000        0.000000              1.000000
# 50%            9.000000       20.000000        0.000000              1.000000
# 75%           14.000000       20.000000        0.000000              1.000000
# max           20.000000       20.000000        1.000000              1.000000
#
#        short_pause_before_play  long_pause_before_play  \
# count            134304.000000           134304.000000
# mean                  0.146920                0.173003
# std                   0.354028                0.378251
# ...

# %%
train.shape, test.shape, tracks_df.shape
# Out:
# ((134304, 21), (33576, 21), (50704, 30))

# %%
msno.matrix(tracks_df.sample(250))
# Out:
# <AxesSubplot:>

# %%
numeric_features = tracks_df.select_dtypes(include=[np.number])

# %%
numeric_features_train = train.select_dtypes(include=[np.number])

# %%
numeric_features_joined = joined_df.select_dtypes(include=[np.number])

# %%
numeric_features_train.corr()
# Out:
#                                session_position  session_length  \
# session_position                       1.000000        0.314241
# session_length                         0.314241        1.000000
# context_switch                        -0.019245       -0.012227
# no_pause_before_play                   0.194480        0.054873
# short_pause_before_play                0.025770       -0.008947
# long_pause_before_play                 0.021981       -0.021348
# hist_user_behavior_n_seekfwd          -0.035195       -0.008633
# hist_user_behavior_n_seekback         -0.022030       -0.014845
# hour_of_day                           -0.005538       -0.012634
#
#                                context_switch  no_pause_before_play  \
# session_position                    -0.019245              0.194480
# session_length                      -0.012227              0.054873
# context_switch                       1.000000              0.003558
# ...

# %%
correlation = numeric_features_joined.corr()

# %%
correlation_track = numeric_features.corr()

# %%
train.skew(), train.kurt()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/nanops.py:494, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     492     return np.array(results)
# --> 494 return func(values, axis=axis, **kwargs)
#
# ...

# %%
f , ax = plt.subplots(figsize = (14,12))

plt.title('Correlation of Numeric Features with Sale Price',y=1,size=16)

sns.heatmap(correlation_track,square = True,  vmax=0.8)
# Out:
# <AxesSubplot:title={'center':'Correlation of Numeric Features with Sale Price'}>

# %%
k= 11
cols = correlation.nlargest(k,'energy')['energy'].index
print(cols)
cm = np.corrcoef(train[cols].values.T)
f , ax = plt.subplots(figsize = (14,12))
sns.heatmap(cm, vmax=.8, linewidths=0.01,square=True,annot=True,cmap='viridis',
            linecolor="white",xticklabels = cols.values ,annot_kws = {'size':12},yticklabels = cols.values)
# Out:
# Index(['energy', 'loudness', 'acoustic_vector_1', 'valence',
#        'acoustic_vector_5', 'mechanism', 'liveness', 'acoustic_vector_7',
#        'tempo', 'acoustic_vector_6', 'acoustic_vector_4'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 4
#       2 cols = correlation.nlargest(k,'energy')['energy'].index
#       3 print(cols)
# ----> 4 cm = np.corrcoef(train[cols].values.T)
#       5 f , ax = plt.subplots(figsize = (14,12))
#       6 sns.heatmap(cm, vmax=.8, linewidths=0.01,square=True,annot=True,cmap='viridis',
#       7             linecolor="white",xticklabels = cols.values ,annot_kws = {'size':12},yticklabels = cols.values)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# ...

# %%
import matplotlib

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 profile.to_notebook_iframe()
#
# File ~/Library/Python/3.9/lib/python/site-packages/typeguard/__init__.py:1033, in typechecked.<locals>.wrapper(*args, **kwargs)
#    1031 memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032 check_argument_types(memo)
# -> 1033 retval = func(*args, **kwargs)
#    1034 try:
#    1035     check_return_type(retval, memo)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ydata_profiling/profile_report.py:500, in ProfileReport.to_notebook_iframe(self)
#     498 with warnings.catch_warnings():
#     499     warnings.simplefilter("ignore")
# --> 500     display(get_notebook_iframe(self.config, self))
#
# ...
